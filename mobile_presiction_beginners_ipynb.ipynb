# %%
import pandas  as pd

# %%
df = pd.read_csv("/content/Cellphone[1].csv")

# %%
df.head()
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
df.shape
# Out:
# (161, 14)

# %%
print("Row number in our data set is {}".format(df.shape[0]))
# Out:
# Row number in our data set is 161

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_id    161 non-null    int64
#  1   Price         161 non-null    int64
#  2   Sale          161 non-null    int64
#  3   weight        161 non-null    float64
#  4   resoloution   161 non-null    float64
#  5   ppi           161 non-null    int64
#  6   cpu core      161 non-null    int64
#  7   cpu freq      161 non-null    float64
#  8   internal mem  161 non-null    float64
#  9   ram           161 non-null    float64
#  10  RearCam       161 non-null    float64
#  11  Front_Cam     161 non-null    float64
#  12  battery       161 non-null    int64
#  13  thickness     161 non-null    float64
# dtypes: float64(8), int64(6)
# memory usage: 17.7 KB

# %%
df.describe()
# Out:
#         Product_id        Price         Sale      weight  resoloution  \
# count   161.000000   161.000000   161.000000  161.000000   161.000000
# mean    675.559006  2215.596273   621.465839  170.426087     5.209938
# std     410.851583   768.187171  1546.618517   92.888612     1.509953
# min      10.000000   614.000000    10.000000   66.000000     1.400000
# 25%     237.000000  1734.000000    37.000000  134.100000     4.800000
# 50%     774.000000  2258.000000   106.000000  153.000000     5.150000
# 75%    1026.000000  2744.000000   382.000000  170.000000     5.500000
# max    1339.000000  4361.000000  9807.000000  753.000000    12.200000
#
#               ppi    cpu core    cpu freq  internal mem         ram  \
# count  161.000000  161.000000  161.000000    161.000000  161.000000
# mean   335.055901    4.857143    1.502832     24.501714    2.204994
# std    134.826659    2.444016    0.599783     28.804773    1.609831
# ...

# %%
df["Price"].idxmin()
# Out:
# 149

# %%
df.iloc[150]
# Out:
# Product_id       826.000
# Price            614.000
# Sale            2171.000
# weight            69.800
# resoloution        1.400
# ppi              129.000
# cpu core           0.000
# cpu freq           0.000
# internal mem       0.000
# ram                0.004
# RearCam            0.000
# Front_Cam          0.000
# battery          800.000
# thickness         14.100
# Name: 150, dtype: float64

# %%
df["Price"].idxmax()
# Out:
# 152

# %%
df.iloc[153]
# Out:
# Product_id       290.00
# Price           4361.00
# Sale            3291.00
# weight           238.00
# resoloution        5.70
# ppi              515.00
# cpu core           8.00
# cpu freq           1.95
# internal mem     128.00
# ram                6.00
# RearCam           12.00
# Front_Cam          8.00
# battery         7000.00
# thickness          7.40
# Name: 153, dtype: float64

# %%
lowestpriced  = int(df.iloc[150][0])
highesttpriced  = int(df.iloc[153][0])

# %%
print(f"prodcut id of lowest price phone is {lowestpriced}.prodcut id of lowest price phone is{highesttpriced}.")
# Out:
# prodcut id of lowest price phone is 826.prodcut id of lowest price phone is290.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace = True)

# %%
df.isna().sum()
# Out:
# Product_id      0
# Price           0
# Sale            0
# weight          0
# resoloution     0
# ppi             0
# cpu core        0
# cpu freq        0
# internal mem    0
# ram             0
# RearCam         0
# Front_Cam       0
# battery         0
# thickness       0
# dtype: int64

# %%
df.corr()
# Out:
#               Product_id     Price      Sale    weight  resoloution       ppi  \
# Product_id      1.000000  0.165136  0.218548  0.035869    -0.017817  0.207271
# Price           0.165136  1.000000  0.273263  0.144555     0.404010  0.817614
# Sale            0.218548  0.273263  1.000000  0.016114     0.017154  0.235896
# weight          0.035869  0.144555  0.016114  1.000000     0.890416 -0.054683
# resoloution    -0.017817  0.404010  0.017154  0.890416     1.000000  0.181292
# ppi             0.207271  0.817614  0.235896 -0.054683     0.181292  1.000000
# cpu core       -0.008634  0.686811  0.069517  0.216257     0.472226  0.487990
# cpu freq        0.092428  0.727383  0.099133  0.222730     0.505454  0.713168
# internal mem    0.261186  0.776738  0.489308  0.098849     0.202660  0.618560
# ram             0.236194  0.896915  0.373127  0.149283     0.327216  0.748724
# RearCam         0.172812  0.739538  0.292164 -0.029448     0.249892  0.774008
# ...

# %%
df.corr()["Price"].sort_values(ascending = False)
# Out:
# Price           1.000000
# ram             0.896915
# ppi             0.817614
# internal mem    0.776738
# RearCam         0.739538
# cpu freq        0.727383
# cpu core        0.686811
# Front_Cam       0.675286
# battery         0.559946
# resoloution     0.404010
# Sale            0.273263
# Product_id      0.165136
# weight          0.144555
# thickness      -0.716773
# Name: Price, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#realtion
sns.heatmap(df.corr(),annot = True,cmap = "rainbow")
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
colorsforx = ["Red","Green","black","blue","yellow"]
colorchanger = 0

# %%
for i in df.columns[:-1]:
  sns.scatterplot(df = df , x = i, y = "Price" , color  = colorsforx[colorchanger])
  plt.show()
  colorchanger +=1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-662d96d62587> in <cell line: 1>()
#       1 for i in df.columns[:-1]:
# ----> 2   sns.scatterplot(df = df , x = i, y = "Price" , color  = colorsforx[colorchanger])
#       3   plt.show()
#       4   colorchanger +=1
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     740
#     741     variables = _ScatterPlotter.get_semantics(locals())
# --> 742     p = _ScatterPlotter(data=data, variables=variables, legend=legend)
#     743
#     744     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     536         )
#     537
# ...
